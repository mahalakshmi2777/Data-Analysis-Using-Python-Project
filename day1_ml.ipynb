# %% [markdown]
# <a href="https://colab.research.google.com/github/mahalakshmi2777/Data-Analysis-Using-Python-Project/blob/main/day1_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mark1=int(input("Enter Mark 1:"))
mark2=int(input("Enter Mark 2:"))
mark3=int(input("Enter Mark 3:"))

Total = Mark1 + Mark2 + Mark3
Average =Total/3

print("Total:",Total)
print("Average:",Average)

if Average >=50:
       print("pass")
else:
      print("Fail")
# Out:
# Enter Mark 1:67
# Enter Mark 2:89
# Enter Mark 3:88
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7695/2426816069.py in <cell line: 0>()
#       3 mark3=int(input("Enter Mark 3:"))
#       4
# ----> 5 Total = Mark1 + Mark2 + Mark3
#       6 Average =Total/3
#       7
#
# NameError: name 'Mark1' is not defined
