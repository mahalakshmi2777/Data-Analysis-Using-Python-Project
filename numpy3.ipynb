# %% [markdown]
# <a href="https://colab.research.google.com/github/mahalakshmi2777/Data-Analysis-Using-Python-Project/blob/main/numpy3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
arr = np.array([10,20,30,40])
print(arr)
# Out:
# [10 20 30 40]
